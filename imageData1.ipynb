# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.24.3

# %%
color = np.array([[[255,0,0],[0,255,0],[0,0,255]]])

plt.imshow(color)

# %%
import keras
# Out:
# e:\anaconda3\envs\tf24\lib\site-packages\tensorflow\python\framework\dtypes.py:513: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   np.object,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import keras
#
# File e:\anaconda3\envs\tf24\lib\site-packages\keras\__init__.py:1
# ----> 1 from . import utils
#       2 from . import activations
#       3 from . import applications
#
# File e:\anaconda3\envs\tf24\lib\site-packages\keras\utils\__init__.py:1
# ----> 1 from tensorflow.keras.utils import *
#
# File e:\anaconda3\envs\tf24\lib\site-packages\tensorflow\__init__.py:41
#      38 import six as _six
#      39 import sys as _sys
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
# ...

# %%
import tensorflow
# Out:
# e:\anaconda3\envs\tf24\lib\site-packages\tensorflow\python\framework\dtypes.py:513: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   np.object,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import tensorflow
#
# File e:\anaconda3\envs\tf24\lib\site-packages\tensorflow\__init__.py:41
#      38 import six as _six
#      39 import sys as _sys
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      44 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File e:\anaconda3\envs\tf24\lib\site-packages\tensorflow\python\__init__.py:46
#      41 from tensorflow.python.eager import context
#      43 # pylint: enable=wildcard-import
#      44
# ...
